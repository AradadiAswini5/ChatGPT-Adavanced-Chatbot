# %% [markdown]
# Phase 1: Install required libraries

# %%
# !pip install openai flask flask-cors gradio tiktoken numpy
# If using FAISS for retrieval, also install: faiss-cpu
# pip install faiss-cpu
# Out:
# Requirement already satisfied: openai in c:\anaconda\envs\aiml\lib\site-packages (2.8.0)
# Requirement already satisfied: flask in c:\anaconda\envs\aiml\lib\site-packages (3.1.2)
# Requirement already satisfied: flask-cors in c:\anaconda\envs\aiml\lib\site-packages (6.0.1)
# Requirement already satisfied: gradio in c:\anaconda\envs\aiml\lib\site-packages (5.49.1)
# Requirement already satisfied: tiktoken in c:\anaconda\envs\aiml\lib\site-packages (0.12.0)
# Requirement already satisfied: numpy in c:\anaconda\envs\aiml\lib\site-packages (2.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\anaconda\envs\aiml\lib\site-packages (from openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\anaconda\envs\aiml\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\anaconda\envs\aiml\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\anaconda\envs\aiml\lib\site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\anaconda\envs\aiml\lib\site-packages (from openai) (2.11.10)
# Requirement already satisfied: sniffio in c:\anaconda\envs\aiml\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\anaconda\envs\aiml\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\anaconda\envs\aiml\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\anaconda\envs\aiml\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in c:\anaconda\envs\aiml\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\anaconda\envs\aiml\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\anaconda\envs\aiml\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\anaconda\envs\aiml\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\anaconda\envs\aiml\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\anaconda\envs\aiml\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: blinker>=1.9.0 in c:\anaconda\envs\aiml\lib\site-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\anaconda\envs\aiml\lib\site-packages (from flask) (8.3.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\anaconda\envs\aiml\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\anaconda\envs\aiml\lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\anaconda\envs\aiml\lib\site-packages (from flask) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\anaconda\envs\aiml\lib\site-packages (from flask) (3.1.3)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: brotli>=1.1.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.121.2)
# Requirement already satisfied: ffmpy in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==1.13.3 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (1.13.3)
# Requirement already satisfied: groovy~=0.1 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (1.1.4)
# Requirement already satisfied: orjson~=3.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (3.11.3)
# Requirement already satisfied: packaging in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (11.3.0)
# Requirement already satisfied: pydub in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.14.5)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.49.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.20.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.38.0)
# Requirement already satisfied: fsspec in c:\anaconda\envs\aiml\lib\site-packages (from gradio-client==1.13.3->gradio) (2025.10.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio-client==1.13.3->gradio) (15.0.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\anaconda\envs\aiml\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: filelock in c:\anaconda\envs\aiml\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.20.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\anaconda\envs\aiml\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.2.0)
# Requirement already satisfied: shellingham in c:\anaconda\envs\aiml\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.5.4)
# Requirement already satisfied: typer-slim in c:\anaconda\envs\aiml\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (0.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\anaconda\envs\aiml\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\envs\aiml\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\anaconda\envs\aiml\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: rich>=10.11.0 in c:\anaconda\envs\aiml\lib\site-packages (from typer<1.0,>=0.12->gradio) (14.2.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\anaconda\envs\aiml\lib\site-packages (from tiktoken) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in c:\anaconda\envs\aiml\lib\site-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: colorama in c:\anaconda\envs\aiml\lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\anaconda\envs\aiml\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\anaconda\envs\aiml\lib\site-packages (from requests>=2.26.0->tiktoken) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\envs\aiml\lib\site-packages (from requests>=2.26.0->tiktoken) (1.26.18)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\anaconda\envs\aiml\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\anaconda\envs\aiml\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\anaconda\envs\aiml\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %%
# !pip install faiss-cpu
# Out:
# Requirement already satisfied: faiss-cpu in c:\anaconda\envs\aiml\lib\site-packages (1.13.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\anaconda\envs\aiml\lib\site-packages (from faiss-cpu) (2.0.0)
# Requirement already satisfied: packaging in c:\anaconda\envs\aiml\lib\site-packages (from faiss-cpu) (25.0)

# %%
# !pip install requests PyPDF2 python-dotenv
# Out:
# Requirement already satisfied: requests in c:\anaconda\envs\aiml\lib\site-packages (2.32.5)
# Requirement already satisfied: PyPDF2 in c:\anaconda\envs\aiml\lib\site-packages (3.0.1)
# Requirement already satisfied: python-dotenv in c:\anaconda\envs\aiml\lib\site-packages (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\anaconda\envs\aiml\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\envs\aiml\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\envs\aiml\lib\site-packages (from requests) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\envs\aiml\lib\site-packages (from requests) (2025.10.5)

# %%
# !pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.1.2-py3-none-any.whl.metadata (16 kB)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers)
#   Downloading transformers-4.57.1-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: tqdm in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (1.5.0)
# Requirement already satisfied: scipy in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (1.16.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (1.1.4)
# Requirement already satisfied: Pillow in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.20.0)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers)
#   Downloading huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: requests in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Downloading tokenizers-0.22.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Downloading safetensors-0.6.2-cp38-abi3-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\anaconda\envs\aiml\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: networkx in c:\anaconda\envs\aiml\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in c:\anaconda\envs\aiml\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\anaconda\envs\aiml\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: sympy==1.13.1 in c:\anaconda\envs\aiml\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\anaconda\envs\aiml\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\anaconda\envs\aiml\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda\envs\aiml\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\anaconda\envs\aiml\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\envs\aiml\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\envs\aiml\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\envs\aiml\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.10.5)
# Requirement already satisfied: joblib>=1.2.0 in c:\anaconda\envs\aiml\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\anaconda\envs\aiml\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Downloading sentence_transformers-5.1.2-py3-none-any.whl (488 kB)
# Downloading transformers-4.57.1-py3-none-any.whl (12.0 MB)
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ------ --------------------------------- 2.1/12.0 MB 13.1 MB/s eta 0:00:01
#    -------------- ------------------------- 4.5/12.0 MB 12.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.8/12.0 MB 12.3 MB/s eta 0:00:01
#    ------------------------------ --------- 9.2/12.0 MB 11.4 MB/s eta 0:00:01
#    -------------------------------------- - 11.5/12.0 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.0/12.0 MB 11.2 MB/s  0:00:01
# Downloading huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 566.1/566.1 kB 3.9 MB/s  0:00:00
# Downloading tokenizers-0.22.1-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------------------------------- -------- 2.1/2.7 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 9.7 MB/s  0:00:00
# Downloading safetensors-0.6.2-cp38-abi3-win_amd64.whl (320 kB)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers, sentence-transformers
#
#   Attempting uninstall: huggingface-hub
#
#     Found existing installation: huggingface_hub 1.1.4
#
#    -------- ------------------------------- 1/5 [huggingface-hub]
#     Uninstalling huggingface_hub-1.1.4:
#    -------- ------------------------------- 1/5 [huggingface-hub]
#       Successfully uninstalled huggingface_hub-1.1.4
#    -------- ------------------------------- 1/5 [huggingface-hub]
#    -------- ------------------------------- 1/5 [huggingface-hub]
#    -------- ------------------------------- 1/5 [huggingface-hub]
#    -------- ------------------------------- 1/5 [huggingface-hub]
#    -------- ------------------------------- 1/5 [huggingface-hub]
#    -------- ------------------------------- 1/5 [huggingface-hub]
#    -------- ------------------------------- 1/5 [huggingface-hub]
#    -------- ------------------------------- 1/5 [huggingface-hub]
#    -------- ------------------------------- 1/5 [huggingface-hub]
#    -------- ------------------------------- 1/5 [huggingface-hub]
#    -------- ------------------------------- 1/5 [huggingface-hub]
#    -------- ------------------------------- 1/5 [huggingface-hub]
#    -------- ------------------------------- 1/5 [huggingface-hub]
#    -------- ------------------------------- 1/5 [huggingface-hub]
#    -------- ------------------------------- 1/5 [huggingface-hub]
#    -------- ------------------------------- 1/5 [huggingface-hub]
#    -------- ------------------------------- 1/5 [huggingface-hub]
#    -------- ------------------------------- 1/5 [huggingface-hub]
#    -------- ------------------------------- 1/5 [huggingface-hub]
#    ---------------- ----------------------- 2/5 [tokenizers]
#    ---------------- ----------------------- 2/5 [tokenizers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    ------------------------ --------------- 3/5 [transformers]
#    -------------------------------- ------- 4/5 [sentence-transformers]
#    -------------------------------- ------- 4/5 [sentence-transformers]
#    -------------------------------- ------- 4/5 [sentence-transformers]
#    -------------------------------- ------- 4/5 [sentence-transformers]
#    -------------------------------- ------- 4/5 [sentence-transformers]
#    -------------------------------- ------- 4/5 [sentence-transformers]
#    -------------------------------- ------- 4/5 [sentence-transformers]
#    -------------------------------- ------- 4/5 [sentence-transformers]
#    -------------------------------- ------- 4/5 [sentence-transformers]
#    -------------------------------- ------- 4/5 [sentence-transformers]
#    -------------------------------- ------- 4/5 [sentence-transformers]
#    -------------------------------- ------- 4/5 [sentence-transformers]
#    -------------------------------- ------- 4/5 [sentence-transformers]
#    -------------------------------- ------- 4/5 [sentence-transformers]
#    ---------------------------------------- 5/5 [sentence-transformers]
#
# Successfully installed huggingface-hub-0.36.0 safetensors-0.6.2 sentence-transformers-5.1.2 tokenizers-0.22.1 transformers-4.57.1

# %% [markdown]
# Phase 2: Initialize Client

# %%
from openai import OpenAI
client = OpenAI(api_key="API KEY")
print("Client initialized")
# Out:
# Client initialized

# %% [markdown]
# Phase 3: Load HuggingFace Embedding Model

# %% [markdown]
# PHASE 4 — Utility functions

# %%
import re

def redact_pii(text):
    text = re.sub(r"\b\d{10}\b", "[REDACTED_PHONE]", text)
    text = re.sub(r"\b\d{12}\b", "[REDACTED_ID]", text)
    text = re.sub(r"[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}", "[REDACTED_EMAIL]", text)
    return text

def chunk_text(text, max_words=250):
    words = text.split()
    return [" ".join(words[i:i+max_words]) for i in range(0, len(words), max_words)]

# Splits long documents into 250-word chunks
# Removes personal information before sending to AI

# %% [markdown]
# LLM Helper Functions: Moderation + Embeddings + Generate

# %%
def moderate(text):
    resp = client.moderations.create(
        model="omni-moderation-latest",
        input=text
    )
    return resp.results[0].flagged

def embed_text(texts):
    resp = client.embeddings.create(
        model="text-embedding-3-large",
        input=texts
    )
    return [d.embedding for d in resp.data]

def embed_query(q):
    resp = client.embeddings.create(
        model="text-embedding-3-large",
        input=[q]
    )
    return resp.data[0].embedding

def generate(messages):
    resp = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=messages,
        temperature=0
    )
    return resp.choices[0].message.content


#Embeds documents
#Embeds user queries
#Safely generates responses
#Moderates inappropriate questions

# %% [markdown]
# Create sample data_txt/ folder and sample file

# %%
from pathlib import Path

Path("data_txt").mkdir(exist_ok=True)

sample_text = """Tamil Nadu Government FAQ

Widow Pension:
Apply at Taluk Office. Need death certificate + ID proof.

Driving Licence Renewal:
Renew through Parivahan. Need existing DL + address proof.

Community Certificate:
Apply at e-Sevai or Tahsildar office with address proof and TC.
"""

Path("data_txt/tn_faq.txt").write_text(sample_text, encoding="utf-8")

print("Sample document created!")
# Out:
# Sample document created!

# %% [markdown]
# Build FAISS Vector Index
#
# This is DOCUMENT INGESTION.

# %% [markdown]
# Define Retrieval Function

# %%
def retrieve(query, k=5):
    index = faiss.read_index("faiss_index.idx")
    meta = json.load(open("faiss_meta.json", "r", encoding="utf-8"))

    q_vec = np.array(embed_query(query), dtype="float32").reshape(1, -1)

    D, I = index.search(q_vec, k)

    results = []
    for idx in I[0]:
        results.append(meta[idx])
    return results

#Retrieves top 5 most similar chunks to user query

# %% [markdown]
# Build Prompt with Context

# %%
def build_prompt(query, contexts):
    ctx_text = "\n---\n".join([c["text"] for c in contexts])

    return [
        {
            "role": "system",
            "content": (
                "You are the Tamil Nadu Government Assistant.\n"
                "Answer ONLY using the context.\n"
                "If answer is not in context, respond:\n"
                "\"Information not available. Visit https://www.tn.gov.in/\""
            )
        },
        {
            "role": "user",
            "content": f"Question: {query}\n\nContext:\n{ctx_text}"
        }
    ]


#Ensures the model answers using ONLY retrieved data
#No hallucination
#Context-aware

# %% [markdown]
# Final Pipeline Function

# %%
def answer_question(query):
    cleaned = redact_pii(query)

    if moderate(cleaned):
        return "This request cannot be processed."

    ctx = retrieve(cleaned)
    messages = build_prompt(cleaned, ctx)
    reply = generate(messages)

    return reply

# %% [markdown]
# Test the System

# %%
print(answer_question("How to apply for widow pension in Tamil Nadu?"))

# %% [markdown]
# Inline Gradio UI

# %%
import gradio as gr

def chat_fn(message):
    return answer_question(message)

ui = gr.Interface(
    fn=chat_fn,
    inputs="text",
    outputs="text",
    title="TN Government Info Assistant",
)

ui.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
